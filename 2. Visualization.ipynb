# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/Pokemon_clean.csv")
df.head()
# Out:
#    Unnamed: 0  #                   Name Type 1  Total  HP  Attack  Defense  \
# 0           0  1              Bulbasaur  Grass    318  45      49       49
# 1           1  2                Ivysaur  Grass    405  60      62       63
# 2           2  3               Venusaur  Grass    525  80      82       83
# 3           3  3  VenusaurMega Venusaur  Grass    625  80     100      123
# 4           4  4             Charmander   Fire    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
strenght = round(pokemon.groupby(["Type 1"])["Attack", "Defense", "Sp. Atk", "Sp. Def"].mean(), 2)
strenght
# Out:
# <ipython-input-14-069c9b93bb1d>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   strenght = round(pokemon.groupby(["Type 1"])["Attack", "Defense", "Sp. Atk", "Sp. Def"].mean(), 2)
#           Attack  Defense  Sp. Atk  Sp. Def
# Type 1
# Bug        70.97    70.72    53.87    64.80
# Dark       88.39    70.23    74.65    69.52
# Dragon    112.12    86.38    96.84    88.84
# Electric   69.09    66.30    90.02    73.70
# Fairy      61.53    65.71    78.53    84.71
# Fighting   96.78    65.93    53.11    64.70
# Fire       84.77    67.77    88.98    72.21
# Flying     78.75    66.25    94.25    72.50
# Ghost      73.78    81.19    79.34    76.47
# Grass      73.21    70.80    77.50    70.43
# Ground     95.75    84.84    56.47    62.75
# Ice        72.75    71.42    77.54    76.29
# Normal     73.47    59.85    55.82    63.72
# Poison     74.68    68.82    60.43    64.39
# ...

# %%
 figure = strenght.plot(marker="o")
figure.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
types = pokemon["Type 1"].value_counts().plot(kind="bar")
